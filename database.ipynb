# %% [markdown]
# ## **Imports**

# %%
from dotenv import load_dotenv
import os
import pandas as pd
from pymongo import MongoClient
import kagglehub
from kaggle.api.kaggle_api_extended import KaggleApi

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ## **MongoDB Setup**
# - sylvr_finance_db

# %%
user = os.getenv("MONGO_USER")
password = os.getenv("MONGO_PASS")

uri = f"mongodb+srv://{user}:{password}@sylvr-financial-cluster.jz9cn66.mongodb.net/?retryWrites=true&w=majority"
client = MongoClient(uri)

# %%
print(client.list_database_names())
# Out:
# ['sample_analytics', 'sylvr_finance_db', 'admin', 'local']

# %%
DB_NAME = os.getenv("DATABASE_NAME")
db = client[DB_NAME]

def get_collection(collection_name):
    return db[collection_name]

# %%
print(db.list_collection_names())
# Out:
# ['stocks', 'EFTs']

# %%
source_db = client["sample_analytics"]
target_db = client["sylvr_finance_db"]

collections = source_db.list_collection_names()

for col_name in collections:
    source_col = source_db[col_name]
    target_col = target_db[col_name]

    documents = source_col.find()
    if documents:
        target_col.insert_many(documents)
        print(f"Moved collection '{col_name}' with {source_col.count_documents({})} documents.")

    source_col.drop()
# Out:
# Moved collection 'transactions' with 1746 documents.
# Moved collection 'accounts' with 1746 documents.
# Moved collection 'customers' with 500 documents.

# %% [markdown]
# ## **Kaggle Dataset**

# %%
api = KaggleApi()
api.authenticate()

# %%
save_path = "Dataset"
os.makedirs(save_path, exist_ok=True)

# %%
api.dataset_download_files("borismarjanovic/price-volume-data-for-all-us-stocks-etfs", path=save_path, unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs

# %% [markdown]
# ## **Uploading to Database**

# %%
def insert_stock_file(file_path, collection):
    symbol = os.path.splitext(os.path.basename(file_path))[0]
    
    try:
        df = pd.read_csv(file_path)
        if df.empty:
            print(f"⚠️ Skipped empty file: {file_path}")
            return
        if 'Date' in df.columns:
            df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
        records = df.to_dict(orient='records')
        for record in records:
            record['symbol'] = symbol
        collection.insert_many(records)
        print(f"✅ Inserted {len(records)} records for {symbol}")
    
    except pd.errors.EmptyDataError:
        print(f"⚠️ EmptyDataError: Skipped file with no data: {file_path}")
    
    except Exception as e:
        print(f"❌ Failed to process {file_path}: {e}")




def load_all_stock_data(folder_path, target_collection):
    collection = db[target_collection]
    for file in os.listdir(folder_path):
        if file.endswith(".txt"):
            insert_stock_file(os.path.join(folder_path, file), collection)

# %%
if __name__ == "__main__":
    STOCKS_DIR = r"Dataset\Stocks"
    ETFS_DIR = r"Dataset\ETFs"
    
    print("Loading Stocks...")
    load_all_stock_data(STOCKS_DIR, "stocks")
    
    print("Loading ETFs...")
    load_all_stock_data(ETFS_DIR, "EFTs")

    print("All data uploaded!")
# Out:
# Loading Stocks...
# ✅ Inserted 505 records for aaap.us
# ✅ Inserted 785 records for aac.us
# ✅ Inserted 989 records for aal.us
# ✅ Inserted 1211 records for aamc.us
# ✅ Inserted 1041 records for aaoi.us
# ✅ Inserted 1717 records for aat.us
# ✅ Inserted 1827 records for abac.us
# ✅ Inserted 1224 records for abbv.us
# ✅ Inserted 1970 records for abcd.us
# ✅ Inserted 885 records for abdc.us
# ✅ Inserted 729 records for abeo.us
# ✅ Inserted 515 records for abeow.us
# ✅ Inserted 470 records for abil.us
# ✅ Inserted 13 records for ablx.us
# ✅ Inserted 875 records for abrn.us
# ✅ Inserted 1144 records for abr_a.us
# ✅ Inserted 1042 records for abr_b.us
# ✅ Inserted 832 records for abr_c.us
# ✅ Inserted 529 records for abtx.us
# ✅ Inserted 862 records for aby.us
# ✅ Inserted 491 records for ac.us
# ✅ Inserted 512 records for acbi.us
# ⚠️ EmptyDataError: Skipped file with no data: Dataset\Stocks\accp.us.txt
# ✅ Inserted 635 records for acerw.us
# ✅ Inserted 1552 records for acfc.us
# ✅ Inserted 59 records for acglo.us
# ✅ Inserted 280 records for acglp.us
# ✅ Inserted 1516 records for achc.us
# ✅ Inserted 379 records for acia.us
# ✅ Inserted 287 records for aciu.us
# ✅ Inserted 6 records for acmr.us
# ✅ Inserted 1707 records for acp.us
# ✅ Inserted 1397 records for acre.us
# ✅ Inserted 529 records for acrs.us
# ✅ Inserted 1674 records for acrx.us
# ✅ Inserted 964 records for acsf.us
# ✅ Inserted 259 records for acsi.us
# ✅ Inserted 1210 records for acst.us
# ✅ Inserted 625 records for acv.us
# ✅ Inserted 637 records for adap.us
# ✅ Inserted 340 records for ades.us
# ✅ Inserted 1129 records for adhd.us
# ✅ Inserted 755 records for adma.us
# ✅ Inserted 906 records for adms.us
# ✅ Inserted 259 records for adnt.us
# ✅ Inserted 105 records for adom.us
# ✅ Inserted 652 records for adro.us
# ✅ Inserted 278 records for adsw.us
# ✅ Inserted 2022 records for adus.us
# ✅ Inserted 829 records for advm.us
# ✅ Inserted 982 records for adxsw.us
# ✅ Inserted 1521 records for aegn.us
# ✅ Inserted 1450 records for aek.us
# ✅ Inserted 590 records for aemd.us
# ✅ Inserted 1020 records for aeri.us
# ✅ Inserted 612 records for aeua.us
# ✅ Inserted 1818 records for afc.us
# ✅ Inserted 789 records for afge.us
# ✅ Inserted 499 records for afgh.us
# ✅ Inserted 1192 records for afh.us
# ✅ Inserted 84 records for afhbl.us
# ✅ Inserted 407 records for afi.us
# ✅ Inserted 799 records for afmd.us
# ✅ Inserted 1290 records for afsd.us
# ✅ Inserted 681 records for afsi_a.us
# ✅ Inserted 678 records for afsi_b.us
# ✅ Inserted 677 records for afsi_c.us
# ✅ Inserted 668 records for afsi_d.us
# ✅ Inserted 417 records for afsi_e.us
# ✅ Inserted 282 records for afsi_f.us
# ✅ Inserted 605 records for afss.us
# ✅ Inserted 543 records for afst.us
# ✅ Inserted 1684 records for aft.us
# ✅ Inserted 591 records for afty.us
# ✅ Inserted 794 records for agfs.us
# ✅ Inserted 664 records for agfsw.us
# ✅ Inserted 378 records for agge.us
# ✅ Inserted 381 records for aggp.us
# ✅ Inserted 510 records for aggy.us
# ✅ Inserted 1197 records for agi.us
# ✅ Inserted 1288 records for agiil.us
# ✅ Inserted 1086 records for agio.us
# ✅ Inserted 405 records for agle.us
# ✅ Inserted 1246 records for agm-a.us
# ✅ Inserted 874 records for agm_a.us
# ✅ Inserted 826 records for agm_b.us
# ✅ Inserted 591 records for agm_c.us
# ✅ Inserted 882 records for agncb.us
# ✅ Inserted 54 records for agncn.us
# ✅ Inserted 610 records for agn_a.us
# ✅ Inserted 1812 records for ago_b.us
# ✅ Inserted 1819 records for ago_e.us
# ✅ Inserted 1817 records for ago_f.us
# ✅ Inserted 479 records for agr.us
# ✅ Inserted 1707 records for agro.us
# ✅ Inserted 876 records for agrx.us
# ✅ Inserted 138 records for agt.us
# ✅ Inserted 916 records for agtc.us
# ✅ Inserted 1139 records for ahh.us
# ✅ Inserted 287 records for ahl_d.us
# ✅ Inserted 1000 records for ahp.us
# ✅ Inserted 102 records for ahpa.us
# ✅ Inserted 169 records for ahpau.us
# ✅ Inserted 133 records for ahpaw.us
# ✅ Inserted 307 records for ahp_b.us
# ✅ Inserted 1818 records for aht_d.us
# ✅ Inserted 333 records for aht_f.us
# ✅ Inserted 266 records for aht_g.us
# ✅ Inserted 53 records for aht_h.us
# ✅ Inserted 30 records for aib-cl.us
# ✅ Inserted 601 records for aic.us
# ✅ Inserted 17 records for aieq.us
# ✅ Inserted 1189 records for aif.us
# ✅ Inserted 1707 records for aig-ws.us
# ✅ Inserted 573 records for aimt.us
# ✅ Inserted 683 records for ainc.us
# ✅ Inserted 316 records for airg.us
# ✅ Inserted 1061 records for airi.us
# ✅ Inserted 662 records for aiv_a.us
# ✅ Inserted 933 records for aiw.us
# ✅ Inserted 1105 records for aiy.us
# ✅ Inserted 111 records for ai_b.us
# ✅ Inserted 693 records for ajx.us
# ✅ Inserted 123 records for ajxa.us
# ✅ Inserted 927 records for akao.us
# ✅ Inserted 921 records for akba.us
# ✅ Inserted 85 records for akca.us
# ✅ Inserted 956 records for aker.us
# ✅ Inserted 1659 records for ako-a.us
# ✅ Inserted 1818 records for ako-b.us
# ✅ Inserted 171 records for akts.us
# ✅ Inserted 911 records for aktx.us
# ✅ Inserted 1646 records for al.us
# ✅ Inserted 887 records for aldr.us
# ✅ Inserted 1254 records for aldw.us
# ✅ Inserted 887 records for aldx.us
# ✅ Inserted 321 records for alfi.us
# ✅ Inserted 1904 records for alim.us
# ✅ Inserted 380 records for aljj.us
# ✅ Inserted 993 records for alle.us
# ✅ Inserted 906 records for ally.us
# ✅ Inserted 681 records for ally_a.us
# ✅ Inserted 1525 records for all_a.us
# ✅ Inserted 1525 records for all_b.us
# ✅ Inserted 1035 records for all_c.us
# ✅ Inserted 976 records for all_d.us
# ✅ Inserted 930 records for all_e.us
# ✅ Inserted 854 records for all_f.us
# ✅ Inserted 7 records for alna.us
# ✅ Inserted 1513 records for alo.us
# ✅ Inserted 608 records for alpn.us
# ✅ Inserted 22 records for alp_o-cl.us
# ✅ Inserted 44 records for alp_q.us
# ✅ Inserted 956 records for alqa.us
# ✅ Inserted 601 records for alrm.us
# ✅ Inserted 95 records for alrn.us
# ✅ Inserted 1426 records for alsn.us
# ✅ Inserted 8 records for altr.us
# ✅ Inserted 491 records for alty.us
# ✅ Inserted 761 records for am.us
# ✅ Inserted 1281 records for amba.us
# ✅ Inserted 1142 records for ambc.us
# ✅ Inserted 1075 records for ambcw.us
# ✅ Inserted 920 records for ambr.us
# ✅ Inserted 983 records for amc.us
# ✅ Inserted 35 records for amca.us
# ✅ Inserted 1602 records for amcx.us
# ✅ Inserted 945 records for amda.us
# ✅ Inserted 721 records for amfw.us
# ✅ Inserted 134 records for amgp.us
# ✅ Inserted 1080 records for amh.us
# ✅ Inserted 836 records for amh_c.us
# ✅ Inserted 370 records for amh_d.us
# ✅ Inserted 345 records for amh_e.us
# ✅ Inserted 139 records for amh_f.us
# ✅ Inserted 81 records for amh_g.us
# ✅ Inserted 1584 records for amid.us
# ✅ Inserted 114 records for amlx.us
# ✅ Inserted 278 records for amma.us
# ✅ Inserted 1632 records for ampe.us
# ✅ Inserted 854 records for amph.us
# ✅ Inserted 1842 records for amrc.us
# ⚠️ EmptyDataError: Skipped file with no data: Dataset\Stocks\amrh.us.txt
# ⚠️ EmptyDataError: Skipped file with no data: Dataset\Stocks\amrhw.us.txt
# ✅ Inserted 911 records for amrk.us
# ✅ Inserted 1792 records for amrs.us
# ✅ Inserted 2209 records for amtx.us
# ✅ Inserted 677 records for amt_b.us
# ✅ Inserted 781 records for amza.us
# ✅ Inserted 202 records for anab.us
# ✅ Inserted 1366 records for ancb.us
# ✅ Inserted 85 records for anda.us
# ✅ Inserted 187 records for andar.us
# ✅ Inserted 32 records for andau.us
# ✅ Inserted 190 records for andaw.us
# ✅ Inserted 1647 records for andx.us
# ✅ Inserted 867 records for anet.us
# ✅ Inserted 1281 records for anfi.us
# ✅ Inserted 1504 records for angi.us
# ✅ Inserted 1692 records for anh_a.us
# ✅ Inserted 1381 records for anh_b.us
# ✅ Inserted 631 records for anh_c.us
# ✅ Inserted 1942 records for anth.us
# ✅ Inserted 630 records for antx.us
# ✅ Inserted 845 records for any.us
# ✅ Inserted 1899 records for aosl.us
# ✅ Inserted 1182 records for apam.us
# ✅ Inserted 676 records for apdnw.us
# ✅ Inserted 1272 records for apen.us
# ✅ Inserted 628 records for aple.us
# ✅ Inserted 2 records for apls.us
# ✅ Inserted 1664 records for apo.us
# ✅ Inserted 316 records for apop.us
# ✅ Inserted 230 records for apopw.us
# ✅ Inserted 172 records for apo_a.us
# ✅ Inserted 601 records for appf.us
# ✅ Inserted 119 records for appn.us
# ✅ Inserted 1114 records for apps.us
# ✅ Inserted 95 records for aprn.us
# ✅ Inserted 287 records for apti.us
# ✅ Inserted 1587 records for apto.us
# ✅ Inserted 1662 records for apts.us
# ✅ Inserted 332 records for apvo.us
# ✅ Inserted 1441 records for apwc.us
# ✅ Inserted 6 records for aq.us
# ✅ Inserted 207 records for aqb.us
# ✅ Inserted 576 records for aqms.us
# ✅ Inserted 240 records for aqn.us
# ✅ Inserted 7 records for aqua.us
# ✅ Inserted 930 records for aqxp.us
# ✅ Inserted 1031 records for ar.us
# ✅ Inserted 395 records for ara.us
# ✅ Inserted 278 records for arch.us
# ✅ Inserted 148 records for arcm.us
# ✅ Inserted 1654 records for arco.us
# ✅ Inserted 1011 records for arcx.us
# ✅ Inserted 169 records for ard.us
# ✅ Inserted 1249 records for ardc.us
# ✅ Inserted 852 records for ardm.us
# ✅ Inserted 858 records for ardx.us
# ✅ Inserted 890 records for ares.us
# ✅ Inserted 357 records for ares_a.us
# ✅ Inserted 423 records for are_d.us
# ✅ Inserted 949 records for args.us
# ✅ Inserted 120 records for argx.us
# ✅ Inserted 1409 records for arh_c.us
# ✅ Inserted 301 records for ari_c.us
# ✅ Inserted 758 records for arkg.us
# ✅ Inserted 753 records for arkk.us
# ✅ Inserted 774 records for arkq.us
# ✅ Inserted 777 records for arkw.us
# ✅ Inserted 987 records for armk.us
# ✅ Inserted 260 records for arnc.us
# ✅ Inserted 160 records for arnc_.us
# ✅ Inserted 229 records for arnc_b.us
# ✅ Inserted 509 records for aroc.us
# ✅ Inserted 1358 records for arr_a.us
# ✅ Inserted 1197 records for arr_b.us
# ✅ Inserted 1484 records for arwr.us
# ✅ Inserted 332 records for asb-ws.us
# ✅ Inserted 726 records for asb.us
# ✅ Inserted 595 records for asb_c.us
# ✅ Inserted 287 records for asb_d.us
# ✅ Inserted 1080 records for asc.us
# ✅ Inserted 331 records for aset.us
# ✅ Inserted 315 records for ashx.us
# ✅ Inserted 280 records for asix.us
# ✅ Inserted 1563 records for asm.us
# ✅ Inserted 1735 records for asmb.us
# ✅ Inserted 705 records for asnd.us
# ⚠️ EmptyDataError: Skipped file with no data: Dataset\Stocks\asns.us.txt
# ✅ Inserted 861 records for aspn.us
# ✅ Inserted 70 records for aspu.us
# ✅ Inserted 1081 records for asrvp.us
# ✅ Inserted 837 records for ast.us
# ✅ Inserted 128 records for asv.us
# ✅ Inserted 38 records for atac.us
# ✅ Inserted 39 records for atacr.us
# ✅ Inserted 44 records for atacu.us
# ✅ Inserted 920 records for aten.us
# ✅ Inserted 233 records for ath.us
# ✅ Inserted 988 records for athm.us
# ✅ Inserted 360 records for atkr.us
# ✅ Inserted 917 records for atnm.us
# ✅ Inserted 106 records for atnx.us
# ✅ Inserted 318 records for atom.us
# ✅ Inserted 1260 records for atos.us
# ✅ Inserted 775 records for atra.us
# ✅ Inserted 785 records for atto.us
# ✅ Inserted 1333 records for attu.us
# ✅ Inserted 100 records for atus.us
# ✅ Inserted 97 records for atxi.us
# ✅ Inserted 83 records for aug.us
# ✅ Inserted 790 records for auph.us
# ✅ Inserted 792 records for aval.us
# ✅ Inserted 1933 records for aveo.us
# ✅ Inserted 703 records for avgr.us
# ✅ Inserted 1012 records for avh.us
# ✅ Inserted 1258 records for avir.us
# ✅ Inserted 515 records for avxl.us
# ✅ Inserted 443 records for avxs.us
# ✅ Inserted 1113 records for awp.us
# ✅ Inserted 612 records for axon.us
# ✅ Inserted 499 records for axsm.us
# ✅ Inserted 1127 records for axs_d.us
# ✅ Inserted 244 records for axs_e.us
# ✅ Inserted 756 records for axta.us
# ✅ Inserted 16 records for aytu.us
# ✅ Inserted 162 records for ayx.us
# ✅ Inserted 270 records for azre.us
# ✅ Inserted 272 records for azrx.us
# ✅ Inserted 150 records for azul.us
# ✅ Inserted 794 records for baba.us
# ✅ Inserted 681 records for bac-ws-a.us
# ✅ Inserted 680 records for bac-ws-b.us
# ✅ Inserted 391 records for bac_a.us
# ✅ Inserted 450 records for bac_c.us
# ✅ Inserted 1819 records for bac_d.us
# ✅ Inserted 1819 records for bac_e.us
# ✅ Inserted 1819 records for bac_i.us
# ✅ Inserted 799 records for bac_w.us
# ✅ Inserted 703 records for bac_y.us
# ✅ Inserted 1756 records for bah.us
# ✅ Inserted 1538 records for banc.us
# ✅ Inserted 624 records for banc_c.us
# ✅ Inserted 654 records for banc_d.us
# ✅ Inserted 445 records for banc_e.us
# ✅ Inserted 1 records for band.us
# ✅ Inserted 886 records for banfp.us
# ✅ Inserted 1604 records for banr.us
# ✅ Inserted 1011 records for banx.us
# ✅ Inserted 46 records for bar.us
# ✅ Inserted 398 records for batra.us
# ✅ Inserted 398 records for batrk.us
# ✅ Inserted 729 records for bbc.us
# ✅ Inserted 1149 records for bbdo.us
# ✅ Inserted 1775 records for bbrg.us
# ⚠️ EmptyDataError: Skipped file with no data: Dataset\Stocks\bbrx.us.txt
# ✅ Inserted 1391 records for bbt_d.us
# ✅ Inserted 1330 records for bbt_e.us
# ✅ Inserted 1267 records for bbt_f.us
# ✅ Inserted 1142 records for bbt_g.us
# ✅ Inserted 422 records for bbt_h.us
# ✅ Inserted 353 records for bbu.us
# ✅ Inserted 86 records for bbx.us
# ✅ Inserted 33 records for bcac.us
# ✅ Inserted 50 records for bcacr.us
# ✅ Inserted 71 records for bcacu.us
# ✅ Inserted 26 records for bcacw.us
# ✅ Inserted 1202 records for bcc.us
# ✅ Inserted 82 records for bcd.us
# ✅ Inserted 1485 records for bcei.us
# ✅ Inserted 130 records for bci.us
# ✅ Inserted 786 records for bcli.us
# ✅ Inserted 1444 records for bcov.us
# ✅ Inserted 1012 records for bcrh.us
# ✅ Inserted 1819 records for bcs_d.us
# ✅ Inserted 586 records for bctf.us
# ✅ Inserted 274 records for bcv_a.us
# ✅ Inserted 1664 records for bcx.us
# ✅ Inserted 16 records for bdcz.us
# ✅ Inserted 315 records for bdc_b.us
# ✅ Inserted 123 records for bdxa.us
# ✅ Inserted 124 records for bedu.us
# ✅ Inserted 2 records for bef.us
# ✅ Inserted 360 records for bemo.us
# ✅ Inserted 1116 records for bep.us
# ✅ Inserted 18 records for bern.us
# ✅ Inserted 1285 records for bery.us
# ✅ Inserted 574 records for betr.us
# ✅ Inserted 1817 records for bf-a.us
# ✅ Inserted 1210 records for bfam.us
# ✅ Inserted 88 records for bfit.us
# ✅ Inserted 1163 records for bfs_c.us
# ✅ Inserted 1291 records for bgb.us
# ✅ Inserted 1350 records for bgca.us
# ✅ Inserted 1269 records for bgh.us
# ✅ Inserted 182 records for bgio.us
# ✅ Inserted 449 records for bgne.us
# ✅ Inserted 636 records for bgsf.us
# ✅ Inserted 1707 records for bgx.us
# ✅ Inserted 82 records for bhac.us
# ✅ Inserted 255 records for bhacr.us
# ✅ Inserted 11 records for bhacu.us
# ✅ Inserted 424 records for bhacw.us
# ✅ Inserted 836 records for bhbk.us
# ✅ Inserted 83 records for bhf.us
# ✅ Inserted 91 records for bhge.us
# ✅ Inserted 134 records for bhvn.us
# ✅ Inserted 8 records for bibl.us
# ✅ Inserted 45 records for bio-b.us
# ✅ Inserted 1136 records for bioa.us
# ✅ Inserted 950 records for bioc.us
# ✅ Inserted 1189 records for bit.us
# ✅ Inserted 1756 records for bita.us
# ✅ Inserted 211 records for bivv.us
# ✅ Inserted 1632 records for bkep.us
# ✅ Inserted 1325 records for bkepp.us
# ✅ Inserted 456 records for bkhu.us
# ✅ Inserted 627 records for bki.us
# ✅ Inserted 1707 records for bku.us
# ✅ Inserted 78 records for bkyi.us
# ✅ Inserted 1294 records for bk_c.us
# ✅ Inserted 262 records for bl.us
# ✅ Inserted 815 records for blbd.us
# ✅ Inserted 731 records for blcm.us
# ✅ Inserted 598 records for bld.us
# ✅ Inserted 177 records for bles.us
# ✅ Inserted 914 records for blfs.us
# ✅ Inserted 236 records for blhy.us
# ✅ Inserted 1325 records for blmn.us
# ✅ Inserted 1533 records for blmt.us
# ✅ Inserted 693 records for blph.us
# ✅ Inserted 1531 records for blrx.us
# ✅ Inserted 1110 records for blue.us
# ✅ Inserted 330 records for blvd.us
# ✅ Inserted 406 records for blvdu.us
# ✅ Inserted 285 records for blvdw.us
# ✅ Inserted 1074 records for bmch.us
# ✅ Inserted 75 records for bmla.us
# ✅ Inserted 61 records for bmlp.us
# ✅ Inserted 1812 records for bml_g.us
# ✅ Inserted 1818 records for bml_h.us
# ✅ Inserted 1819 records for bml_i.us
# ✅ Inserted 1819 records for bml_j.us
# ✅ Inserted 1819 records for bml_l.us
# ✅ Inserted 300 records for bmra.us
# ✅ Inserted 75 records for bndc.us
# ✅ Inserted 575 records for bned.us
# ✅ Inserted 1047 records for bnft.us
# ✅ Inserted 783 records for bntc.us
# ✅ Inserted 183 records for bntcw.us
# ✅ Inserted 405 records for bofil.us
# ✅ Inserted 635 records for boja.us
# ✅ Inserted 347 records for bokfl.us
# ✅ Inserted 333 records for bold.us
# ⚠️ EmptyDataError: Skipped file with no data: Dataset\Stocks\bolt.us.txt
# ✅ Inserted 107 records for bomn.us
# ✅ Inserted 765 records for boot.us
# ✅ Inserted 1869 records for born.us
# ✅ Inserted 186 records for boss.us
# ✅ Inserted 1136 records for botj.us
# ✅ Inserted 291 records for botz.us
# ✅ Inserted 708 records for box.us
# ⚠️ EmptyDataError: Skipped file with no data: Dataset\Stocks\boxl.us.txt
# ✅ Inserted 1035 records for bpfhp.us
# ✅ Inserted 670 records for bpfhw.us
# ✅ Inserted 641 records for bpmc.us
# ✅ Inserted 12 records for bpmp.us
# ✅ Inserted 712 records for bpmx.us
# ✅ Inserted 1533 records for bpopm.us
# ✅ Inserted 1766 records for bpopn.us
# ✅ Inserted 73 records for bprn.us
# ✅ Inserted 2126 records for bpth.us
# ✅ Inserted 1154 records for bpy.us
# ✅ Inserted 11 records for brac.us
# ✅ Inserted 11 records for bracr.us
# ✅ Inserted 27 records for bracu.us
# ✅ Inserted 13 records for bracw.us
# ✅ Inserted 915 records for brg.us
# ✅ Inserted 16 records for brgl.us
# ✅ Inserted 514 records for brg_a.us
# ✅ Inserted 301 records for brg_c.us
# ✅ Inserted 263 records for brg_d.us
# ✅ Inserted 271 records for brqs.us
# ✅ Inserted 345 records for brqsw.us
# ✅ Inserted 1128 records for brss.us
# ✅ Inserted 1017 records for brx.us
# ✅ Inserted 513 records for bscp.us
# ✅ Inserted 283 records for bscq.us
# ✅ Inserted 25 records for bscr.us
# ✅ Inserted 1618 records for bsf.us
# ✅ Inserted 1867 records for bsft.us
# ✅ Inserted 489 records for bsjn.us
# ✅ Inserted 282 records for bsjo.us
# ✅ Inserted 28 records for bsjp.us
# ✅ Inserted 640 records for bsm.us
# ✅ Inserted 1291 records for bsmx.us
# ✅ Inserted 766 records for bst.us
# ✅ Inserted 38 records for bsti.us
# ✅ Inserted 225 records for bswn.us
# ✅ Inserted 176 records for btec.us
# ✅ Inserted 1119 records for btg.us
# ✅ Inserted 1310 records for btt.us
# ✅ Inserted 154 records for btu.us
# ✅ Inserted 14 records for btu_.us
# ✅ Inserted 688 records for btx-ws.us
# ✅ Inserted 584 records for buff.us
# ✅ Inserted 1500 records for bui.us
# ✅ Inserted 1276 records for bur.us
# ✅ Inserted 1037 records for burl.us
# ✅ Inserted 257 records for buz.us
# ✅ Inserted 1440 records for bv.us
# ✅ Inserted 83 records for bval.us
# ✅ Inserted 561 records for bvxv.us
# ✅ Inserted 364 records for bvxvw.us
# ✅ Inserted 598 records for bw.us
# ✅ Inserted 864 records for bwfg.us
# ✅ Inserted 1417 records for bwg.us
# ✅ Inserted 1545 records for bwina.us
# ✅ Inserted 1080 records for bwl-a.us
# ✅ Inserted 598 records for bwxt.us
# ✅ Inserted 1293 records for bxe.us
# ⚠️ EmptyDataError: Skipped file with no data: Dataset\Stocks\bxg.us.txt
# ✅ Inserted 1162 records for bxp_b.us
# ✅ Inserted 94 records for by.us
# ❌ Failed to process Dataset\Stocks\bybk.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\bybk.us.txt'
# ❌ Failed to process Dataset\Stocks\byfc.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\byfc.us.txt'
# ✅ Inserted 170 records for bysi.us
# ✅ Inserted 626 records for bzun.us
# ✅ Inserted 669 records for c-ws-a.us
# ✅ Inserted 598 records for cabo.us
# ✅ Inserted 130 records for cacg.us
# ❌ Failed to process Dataset\Stocks\cadc.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cadc.us.txt'
# ✅ Inserted 148 records for cade.us
# ✅ Inserted 606 records for cafd.us
# ❌ Failed to process Dataset\Stocks\cala.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cala.us.txt'
# ✅ Inserted 101 records for calf.us
# ❌ Failed to process Dataset\Stocks\calx.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\calx.us.txt'
# ❌ Failed to process Dataset\Stocks\canf.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\canf.us.txt'
# ❌ Failed to process Dataset\Stocks\capl.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\capl.us.txt'
# ❌ Failed to process Dataset\Stocks\capr.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\capr.us.txt'
# ❌ Failed to process Dataset\Stocks\cara.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cara.us.txt'
# ❌ Failed to process Dataset\Stocks\carb.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\carb.us.txt'
# ✅ Inserted 22 records for carg.us
# ❌ Failed to process Dataset\Stocks\caro.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\caro.us.txt'
# ✅ Inserted 114 records for cars.us
# ❌ Failed to process Dataset\Stocks\cart.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cart.us.txt'
# ❌ Failed to process Dataset\Stocks\carv.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\carv.us.txt'
# ✅ Inserted 602 records for catb.us
# ✅ Inserted 13 records for catc.us
# ✅ Inserted 372 records for cath.us
# ❌ Failed to process Dataset\Stocks\cats.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cats.us.txt'
# ✅ Inserted 29 records for catyw.us
# ❌ Failed to process Dataset\Stocks\cba.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cba.us.txt'
# ❌ Failed to process Dataset\Stocks\cbay.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cbay.us.txt'
# ❌ Failed to process Dataset\Stocks\cbb_b.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cbb_b.us.txt'
# ❌ Failed to process Dataset\Stocks\cbf.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cbf.us.txt'
# ❌ Failed to process Dataset\Stocks\cbfv.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cbfv.us.txt'
# ✅ Inserted 96 records for cbh.us
# ❌ Failed to process Dataset\Stocks\cbl_d.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cbl_d.us.txt'
# ❌ Failed to process Dataset\Stocks\cbl_e.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cbl_e.us.txt'
# ❌ Failed to process Dataset\Stocks\cbmg.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cbmg.us.txt'
# ✅ Inserted 214 records for cbmxw.us
# ✅ Inserted 32 records for cbo.us
# ❌ Failed to process Dataset\Stocks\cbpx.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cbpx.us.txt'
# ❌ Failed to process Dataset\Stocks\cbs-a.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cbs-a.us.txt'
# ❌ Failed to process Dataset\Stocks\cbshp.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cbshp.us.txt'
# ✅ Inserted 3 records for cbtx.us
# ✅ Inserted 21 records for cbx.us
# ❌ Failed to process Dataset\Stocks\cc.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cc.us.txt'
# ❌ Failed to process Dataset\Stocks\cccr.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cccr.us.txt'
# ❌ Failed to process Dataset\Stocks\ccd.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ccd.us.txt'
# ❌ Failed to process Dataset\Stocks\ccih.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ccih.us.txt'
# ✅ Inserted 71 records for cci_a.us
# ❌ Failed to process Dataset\Stocks\cclp.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cclp.us.txt'
# ✅ Inserted 119 records for ccor.us
# ❌ Failed to process Dataset\Stocks\ccrc.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ccrc.us.txt'
# ❌ Failed to process Dataset\Stocks\ccs.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ccs.us.txt'
# ✅ Inserted 1 records for ccv-cl.us
# ❌ Failed to process Dataset\Stocks\ccv.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ccv.us.txt'
# ❌ Failed to process Dataset\Stocks\ccxi.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ccxi.us.txt'
# ❌ Failed to process Dataset\Stocks\ccz.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ccz.us.txt'
# ❌ Failed to process Dataset\Stocks\cdc.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cdc.us.txt'
# ❌ Failed to process Dataset\Stocks\cdev.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cdev.us.txt'
# ❌ Failed to process Dataset\Stocks\cdk.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cdk.us.txt'
# ❌ Failed to process Dataset\Stocks\cdl.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cdl.us.txt'
# ❌ Failed to process Dataset\Stocks\cdna.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cdna.us.txt'
# ❌ Failed to process Dataset\Stocks\cdr_b.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cdr_b.us.txt'
# ✅ Inserted 55 records for cdr_c.us
# ❌ Failed to process Dataset\Stocks\cdtx.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cdtx.us.txt'
# ❌ Failed to process Dataset\Stocks\cdw.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cdw.us.txt'
# ❌ Failed to process Dataset\Stocks\cdxc.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cdxc.us.txt'
# ❌ Failed to process Dataset\Stocks\cdxs.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cdxs.us.txt'
# ✅ Inserted 164 records for cefs.us
# ✅ Inserted 38 records for celc.us
# ❌ Failed to process Dataset\Stocks\celgz.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\celgz.us.txt'
# ✅ Inserted 120 records for celh.us
# ❌ Failed to process Dataset\Stocks\celp.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\celp.us.txt'
# ❌ Failed to process Dataset\Stocks\cemb.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cemb.us.txt'
# ❌ Failed to process Dataset\Stocks\cen.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cen.us.txt'
# ❌ Failed to process Dataset\Stocks\cerc.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cerc.us.txt'
# ❌ Failed to process Dataset\Stocks\cercw.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cercw.us.txt'
# ❌ Failed to process Dataset\Stocks\cetx.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cetx.us.txt'
# ✅ Inserted 140 records for cetxp.us
# ✅ Inserted 118 records for cetxw.us
# ✅ Inserted 11 records for cey.us
# ❌ Failed to process Dataset\Stocks\cez.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cez.us.txt'
# ❌ Failed to process Dataset\Stocks\cfa.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cfa.us.txt'
# ❌ Failed to process Dataset\Stocks\cfbi.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cfbi.us.txt'
# ❌ Failed to process Dataset\Stocks\cfco.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cfco.us.txt'
# ❌ Failed to process Dataset\Stocks\cfcou.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cfcou.us.txt'
# ❌ Failed to process Dataset\Stocks\cfcow.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cfcow.us.txt'
# ❌ Failed to process Dataset\Stocks\cfc_b.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cfc_b.us.txt'
# ❌ Failed to process Dataset\Stocks\cfg.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cfg.us.txt'
# ❌ Failed to process Dataset\Stocks\cfms.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cfms.us.txt'
# ❌ Failed to process Dataset\Stocks\cfo.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cfo.us.txt'
# ❌ Failed to process Dataset\Stocks\cfrx.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cfrx.us.txt'
# ❌ Failed to process Dataset\Stocks\cfr_a.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cfr_a.us.txt'
# ❌ Failed to process Dataset\Stocks\cg.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cg.us.txt'
# ❌ Failed to process Dataset\Stocks\cgbd.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cgbd.us.txt'
# ❌ Failed to process Dataset\Stocks\cgix.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cgix.us.txt'
# ❌ Failed to process Dataset\Stocks\chad.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\chad.us.txt'
# ❌ Failed to process Dataset\Stocks\chct.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\chct.us.txt'
# ❌ Failed to process Dataset\Stocks\chef.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\chef.us.txt'
# ❌ Failed to process Dataset\Stocks\chek.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\chek.us.txt'
# ❌ Failed to process Dataset\Stocks\chekw.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\chekw.us.txt'
# ❌ Failed to process Dataset\Stocks\chfs.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\chfs.us.txt'
# ❌ Failed to process Dataset\Stocks\chgg.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\chgg.us.txt'
# ✅ Inserted 21 records for chgx.us
# ❌ Failed to process Dataset\Stocks\chkr.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\chkr.us.txt'
# ❌ Failed to process Dataset\Stocks\chk_d.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\chk_d.us.txt'
# ❌ Failed to process Dataset\Stocks\chma.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\chma.us.txt'
# ❌ Failed to process Dataset\Stocks\chmg.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\chmg.us.txt'
# ❌ Failed to process Dataset\Stocks\chmi.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\chmi.us.txt'
# ✅ Inserted 57 records for chmi_a.us
# ❌ Failed to process Dataset\Stocks\chrs.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\chrs.us.txt'
# ❌ Failed to process Dataset\Stocks\chscl.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\chscl.us.txt'
# ❌ Failed to process Dataset\Stocks\chscm.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\chscm.us.txt'
# ❌ Failed to process Dataset\Stocks\chscn.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\chscn.us.txt'
# ❌ Failed to process Dataset\Stocks\chsco.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\chsco.us.txt'
# ❌ Failed to process Dataset\Stocks\chscp.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\chscp.us.txt'
# ❌ Failed to process Dataset\Stocks\chuba.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\chuba.us.txt'
# ❌ Failed to process Dataset\Stocks\chubk.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\chubk.us.txt'
# ❌ Failed to process Dataset\Stocks\chuy.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\chuy.us.txt'
# ❌ Failed to process Dataset\Stocks\cibr.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cibr.us.txt'
# ✅ Inserted 47 records for cic-u.us
# ✅ Inserted 21 records for cic-ws.us
# ✅ Inserted 18 records for cic.us
# ❌ Failed to process Dataset\Stocks\cid.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cid.us.txt'
# ❌ Failed to process Dataset\Stocks\cifs.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cifs.us.txt'
# ❌ Failed to process Dataset\Stocks\cig-c.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cig-c.us.txt'
# ❌ Failed to process Dataset\Stocks\cigi.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cigi.us.txt'
# ❌ Failed to process Dataset\Stocks\cil.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cil.us.txt'
# ❌ Failed to process Dataset\Stocks\cim_a.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cim_a.us.txt'
# ❌ Failed to process Dataset\Stocks\cim_b.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cim_b.us.txt'
# ❌ Failed to process Dataset\Stocks\cinr.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cinr.us.txt'
# ❌ Failed to process Dataset\Stocks\cio.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cio.us.txt'
# ❌ Failed to process Dataset\Stocks\cio_a.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cio_a.us.txt'
# ✅ Inserted 9 records for cisn-ws.us
# ❌ Failed to process Dataset\Stocks\cisn.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cisn.us.txt'
# ❌ Failed to process Dataset\Stocks\civbp.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\civbp.us.txt'
# ❌ Failed to process Dataset\Stocks\civi.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\civi.us.txt'
# ❌ Failed to process Dataset\Stocks\ciz.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ciz.us.txt'
# ❌ Failed to process Dataset\Stocks\cj.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cj.us.txt'
# ❌ Failed to process Dataset\Stocks\cjjd.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cjjd.us.txt'
# ❌ Failed to process Dataset\Stocks\ckpt.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ckpt.us.txt'
# ❌ Failed to process Dataset\Stocks\cldc.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cldc.us.txt'
# ❌ Failed to process Dataset\Stocks\cldr.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cldr.us.txt'
# ❌ Failed to process Dataset\Stocks\clir.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\clir.us.txt'
# ❌ Failed to process Dataset\Stocks\clirw.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\clirw.us.txt'
# ❌ Failed to process Dataset\Stocks\clls.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\clls.us.txt'
# ❌ Failed to process Dataset\Stocks\clns.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\clns.us.txt'
# ❌ Failed to process Dataset\Stocks\clns_b.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\clns_b.us.txt'
# ✅ Inserted 20 records for clns_c-cl.us
# ❌ Failed to process Dataset\Stocks\clns_d.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\clns_d.us.txt'
# ❌ Failed to process Dataset\Stocks\clns_e.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\clns_e.us.txt'
# ❌ Failed to process Dataset\Stocks\clns_g.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\clns_g.us.txt'
# ❌ Failed to process Dataset\Stocks\clns_h.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\clns_h.us.txt'
# ❌ Failed to process Dataset\Stocks\clns_i.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\clns_i.us.txt'
# ✅ Inserted 33 records for clns_j.us
# ❌ Failed to process Dataset\Stocks\clnt.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\clnt.us.txt'
# ❌ Failed to process Dataset\Stocks\clpr.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\clpr.us.txt'
# ❌ Failed to process Dataset\Stocks\clrb.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\clrb.us.txt'
# ❌ Failed to process Dataset\Stocks\clrbw.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\clrbw.us.txt'
# ❌ Failed to process Dataset\Stocks\clrbz.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\clrbz.us.txt'
# ❌ Failed to process Dataset\Stocks\clsd.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\clsd.us.txt'
# ✅ Inserted 17 records for cltl.us
# ❌ Failed to process Dataset\Stocks\clvs.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\clvs.us.txt'
# ❌ Failed to process Dataset\Stocks\clxt.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\clxt.us.txt'
# ❌ Failed to process Dataset\Stocks\clyh.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\clyh.us.txt'
# ❌ Failed to process Dataset\Stocks\cma-ws.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cma-ws.us.txt'
# ❌ Failed to process Dataset\Stocks\cmcl.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cmcl.us.txt'
# ❌ Failed to process Dataset\Stocks\cmcm.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cmcm.us.txt'
# ❌ Failed to process Dataset\Stocks\cmfn.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cmfn.us.txt'
# ❌ Failed to process Dataset\Stocks\cmo_e.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cmo_e.us.txt'
# ❌ Failed to process Dataset\Stocks\cmre.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cmre.us.txt'
# ❌ Failed to process Dataset\Stocks\cmre_b.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cmre_b.us.txt'
# ❌ Failed to process Dataset\Stocks\cmre_c.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cmre_c.us.txt'
# ❌ Failed to process Dataset\Stocks\cmre_d.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cmre_d.us.txt'
# ❌ Failed to process Dataset\Stocks\cmrx.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cmrx.us.txt'
# ✅ Inserted 4 records for cmss.us
# ✅ Inserted 5 records for cmssr.us
# ✅ Inserted 12 records for cmssu.us
# ✅ Inserted 5 records for cmssw.us
# ❌ Failed to process Dataset\Stocks\cms_b.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cms_b.us.txt'
# ❌ Failed to process Dataset\Stocks\cmta.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cmta.us.txt'
# ✅ Inserted 26 records for cnac.us
# ✅ Inserted 41 records for cnacr.us
# ❌ Failed to process Dataset\Stocks\cnacu.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cnacu.us.txt'
# ✅ Inserted 33 records for cnacw.us
# ❌ Failed to process Dataset\Stocks\cnat.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cnat.us.txt'
# ❌ Failed to process Dataset\Stocks\cnce.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cnce.us.txt'
# ❌ Failed to process Dataset\Stocks\cncr.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cncr.us.txt'
# ❌ Failed to process Dataset\Stocks\cndf.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cndf.us.txt'
# ❌ Failed to process Dataset\Stocks\cndt.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cndt.us.txt'
# ❌ Failed to process Dataset\Stocks\cnfr.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cnfr.us.txt'
# ❌ Failed to process Dataset\Stocks\cnhi.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cnhi.us.txt'
# ✅ Inserted 6 records for cnhx.us
# ❌ Failed to process Dataset\Stocks\cnnx.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cnnx.us.txt'
# ❌ Failed to process Dataset\Stocks\cnsf.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cnsf.us.txt'
# ❌ Failed to process Dataset\Stocks\cnxc.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cnxc.us.txt'
# ❌ Failed to process Dataset\Stocks\cnxr.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cnxr.us.txt'
# ❌ Failed to process Dataset\Stocks\cnya.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cnya.us.txt'
# ❌ Failed to process Dataset\Stocks\coda.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\coda.us.txt'
# ❌ Failed to process Dataset\Stocks\codi_a.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\codi_a.us.txt'
# ❌ Failed to process Dataset\Stocks\codx.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\codx.us.txt'
# ❌ Failed to process Dataset\Stocks\coe.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\coe.us.txt'
# ❌ Failed to process Dataset\Stocks\cof-ws.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cof-ws.us.txt'
# ❌ Failed to process Dataset\Stocks\cof_c.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cof_c.us.txt'
# ❌ Failed to process Dataset\Stocks\cof_d.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cof_d.us.txt'
# ❌ Failed to process Dataset\Stocks\cof_f.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cof_f.us.txt'
# ❌ Failed to process Dataset\Stocks\cof_g.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cof_g.us.txt'
# ❌ Failed to process Dataset\Stocks\cof_h.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cof_h.us.txt'
# ❌ Failed to process Dataset\Stocks\cof_p.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cof_p.us.txt'
# ❌ Failed to process Dataset\Stocks\coll.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\coll.us.txt'
# ❌ Failed to process Dataset\Stocks\com.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\com.us.txt'
# ❌ Failed to process Dataset\Stocks\comb.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\comb.us.txt'
# ✅ Inserted 38 records for comg.us
# ❌ Failed to process Dataset\Stocks\comm.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\comm.us.txt'
# ❌ Failed to process Dataset\Stocks\cone.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cone.us.txt'
# ❌ Failed to process Dataset\Stocks\cori.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cori.us.txt'
# ❌ Failed to process Dataset\Stocks\corr_a.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\corr_a.us.txt'
# ✅ Inserted 18 records for cor_a-cl.us
# ❌ Failed to process Dataset\Stocks\cor_a.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cor_a.us.txt'
# ❌ Failed to process Dataset\Stocks\cotv.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cotv.us.txt'
# ❌ Failed to process Dataset\Stocks\coty.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\coty.us.txt'
# ❌ Failed to process Dataset\Stocks\coup.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\coup.us.txt'
# ❌ Failed to process Dataset\Stocks\cownl.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cownl.us.txt'
# ❌ Failed to process Dataset\Stocks\cowz.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cowz.us.txt'
# ❌ Failed to process Dataset\Stocks\cpac.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cpac.us.txt'
# ❌ Failed to process Dataset\Stocks\cpah.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cpah.us.txt'
# ❌ Failed to process Dataset\Stocks\cpe_a.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cpe_a.us.txt'
# ❌ Failed to process Dataset\Stocks\cpix.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cpix.us.txt'
# ❌ Failed to process Dataset\Stocks\cps.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cps.us.txt'
# ❌ Failed to process Dataset\Stocks\cpsh.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cpsh.us.txt'
# ❌ Failed to process Dataset\Stocks\cpta.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cpta.us.txt'
# ❌ Failed to process Dataset\Stocks\cptag.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cptag.us.txt'
# ❌ Failed to process Dataset\Stocks\cptal.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cptal.us.txt'
# ❌ Failed to process Dataset\Stocks\cqh.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cqh.us.txt'
# ❌ Failed to process Dataset\Stocks\crak.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\crak.us.txt'
# ❌ Failed to process Dataset\Stocks\crbp.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\crbp.us.txt'
# ❌ Failed to process Dataset\Stocks\crc.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\crc.us.txt'
# ❌ Failed to process Dataset\Stocks\crcm.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\crcm.us.txt'
# ❌ Failed to process Dataset\Stocks\crd-a.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\crd-a.us.txt'
# ❌ Failed to process Dataset\Stocks\crhm.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\crhm.us.txt'
# ❌ Failed to process Dataset\Stocks\crmd.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\crmd.us.txt'
# ❌ Failed to process Dataset\Stocks\crsp.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\crsp.us.txt'
# ❌ Failed to process Dataset\Stocks\crto.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\crto.us.txt'
# ❌ Failed to process Dataset\Stocks\crvs.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\crvs.us.txt'
# ❌ Failed to process Dataset\Stocks\csa.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\csa.us.txt'
# ❌ Failed to process Dataset\Stocks\csb.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\csb.us.txt'
# ❌ Failed to process Dataset\Stocks\csbr.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\csbr.us.txt'
# ❌ Failed to process Dataset\Stocks\csf.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\csf.us.txt'
# ❌ Failed to process Dataset\Stocks\cslt.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cslt.us.txt'
# ❌ Failed to process Dataset\Stocks\csml.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\csml.us.txt'
# ❌ Failed to process Dataset\Stocks\csod.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\csod.us.txt'
# ❌ Failed to process Dataset\Stocks\csra.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\csra.us.txt'
# ❌ Failed to process Dataset\Stocks\csse.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\csse.us.txt'
# ❌ Failed to process Dataset\Stocks\cste.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cste.us.txt'
# ❌ Failed to process Dataset\Stocks\cstm.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cstm.us.txt'
# ❌ Failed to process Dataset\Stocks\cstr.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cstr.us.txt'
# ❌ Failed to process Dataset\Stocks\cswi.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cswi.us.txt'
# ❌ Failed to process Dataset\Stocks\ctaa.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ctaa.us.txt'
# ❌ Failed to process Dataset\Stocks\ctbb.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ctbb.us.txt'
# ❌ Failed to process Dataset\Stocks\ctdd.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ctdd.us.txt'
# ❌ Failed to process Dataset\Stocks\ctek.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ctek.us.txt'
# ❌ Failed to process Dataset\Stocks\ctic.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ctic.us.txt'
# ❌ Failed to process Dataset\Stocks\ctlt.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ctlt.us.txt'
# ❌ Failed to process Dataset\Stocks\ctmx.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ctmx.us.txt'
# ❌ Failed to process Dataset\Stocks\ctr.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ctr.us.txt'
# ❌ Failed to process Dataset\Stocks\ctre.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ctre.us.txt'
# ❌ Failed to process Dataset\Stocks\ctrl.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ctrl.us.txt'
# ❌ Failed to process Dataset\Stocks\ctrv.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ctrv.us.txt'
# ❌ Failed to process Dataset\Stocks\ctt.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ctt.us.txt'
# ❌ Failed to process Dataset\Stocks\ctu.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ctu.us.txt'
# ❌ Failed to process Dataset\Stocks\ctv.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ctv.us.txt'
# ❌ Failed to process Dataset\Stocks\ctw.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ctw.us.txt'
# ❌ Failed to process Dataset\Stocks\ctx.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ctx.us.txt'
# ❌ Failed to process Dataset\Stocks\ctxr.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ctxr.us.txt'
# ❌ Failed to process Dataset\Stocks\ctxrw.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ctxrw.us.txt'
# ❌ Failed to process Dataset\Stocks\cty.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cty.us.txt'
# ❌ Failed to process Dataset\Stocks\ctz.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ctz.us.txt'
# ❌ Failed to process Dataset\Stocks\cube.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cube.us.txt'
# ❌ Failed to process Dataset\Stocks\cubi.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cubi.us.txt'
# ❌ Failed to process Dataset\Stocks\cubi_c.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cubi_c.us.txt'
# ❌ Failed to process Dataset\Stocks\cubi_d.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cubi_d.us.txt'
# ❌ Failed to process Dataset\Stocks\cubi_e.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cubi_e.us.txt'
# ❌ Failed to process Dataset\Stocks\cubi_f.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cubi_f.us.txt'
# ❌ Failed to process Dataset\Stocks\cubn.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cubn.us.txt'
# ❌ Failed to process Dataset\Stocks\cubs.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cubs.us.txt'
# ❌ Failed to process Dataset\Stocks\cuda.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cuda.us.txt'
# ❌ Failed to process Dataset\Stocks\cumb.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cumb.us.txt'
# ❌ Failed to process Dataset\Stocks\cunb.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cunb.us.txt'
# ❌ Failed to process Dataset\Stocks\cuo.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\cuo.us.txt'
# ...
# ❌ Failed to process Dataset\Stocks\yrcw.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\yrcw.us.txt'
# ❌ Failed to process Dataset\Stocks\yrd.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\yrd.us.txt'
# ❌ Failed to process Dataset\Stocks\ytra.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\ytra.us.txt'
# ❌ Failed to process Dataset\Stocks\yumc.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\yumc.us.txt'
# ❌ Failed to process Dataset\Stocks\yume.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\yume.us.txt'
# ❌ Failed to process Dataset\Stocks\yy.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\yy.us.txt'
# ❌ Failed to process Dataset\Stocks\z.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\z.us.txt'
# ❌ Failed to process Dataset\Stocks\zais.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zais.us.txt'
# ❌ Failed to process Dataset\Stocks\zayo.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zayo.us.txt'
# ❌ Failed to process Dataset\Stocks\zbio.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zbio.us.txt'
# ❌ Failed to process Dataset\Stocks\zbk.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zbk.us.txt'
# ❌ Failed to process Dataset\Stocks\zbzx.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zbzx.us.txt'
# ❌ Failed to process Dataset\Stocks\zb_a.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zb_a.us.txt'
# ❌ Failed to process Dataset\Stocks\zb_g.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zb_g.us.txt'
# ❌ Failed to process Dataset\Stocks\zb_h.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zb_h.us.txt'
# ❌ Failed to process Dataset\Stocks\zdge.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zdge.us.txt'
# ❌ Failed to process Dataset\Stocks\zeal.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zeal.us.txt'
# ❌ Failed to process Dataset\Stocks\zen.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zen.us.txt'
# ❌ Failed to process Dataset\Stocks\zfgn.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zfgn.us.txt'
# ❌ Failed to process Dataset\Stocks\zg.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zg.us.txt'
# ❌ Failed to process Dataset\Stocks\zgnx.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zgnx.us.txt'
# ❌ Failed to process Dataset\Stocks\zionw.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zionw.us.txt'
# ❌ Failed to process Dataset\Stocks\zionz.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zionz.us.txt'
# ✅ Inserted 8 records for zjzzt.us
# ❌ Failed to process Dataset\Stocks\zkin.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zkin.us.txt'
# ✅ Inserted 38 records for zlab.us
# ❌ Failed to process Dataset\Stocks\znga.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\znga.us.txt'
# ⚠️ EmptyDataError: Skipped file with no data: Dataset\Stocks\znwaa.us.txt
# ❌ Failed to process Dataset\Stocks\zoes.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zoes.us.txt'
# ❌ Failed to process Dataset\Stocks\zsan.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zsan.us.txt'
# ❌ Failed to process Dataset\Stocks\zto.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zto.us.txt'
# ❌ Failed to process Dataset\Stocks\zts.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zts.us.txt'
# ✅ Inserted 5 records for zvv.us
# ❌ Failed to process Dataset\Stocks\zx.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zx.us.txt'
# ❌ Failed to process Dataset\Stocks\zyme.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zyme.us.txt'
# ❌ Failed to process Dataset\Stocks\zyne.us.txt: [Errno 2] No such file or directory: 'Dataset\\Stocks\\zyne.us.txt'
# Loading ETFs...
# ✅ Inserted 272 records for actx.us
# ✅ Inserted 403 records for acwf.us
# ✅ Inserted 780 records for agnd.us
# ✅ Inserted 849 records for agzd.us
# ✅ Inserted 921 records for airr.us
# ✅ Inserted 776 records for alts.us
# ✅ Inserted 263 records for amjl.us
# ✅ Inserted 1009 records for ashr.us
# ✅ Inserted 872 records for ashs.us
# ✅ Inserted 588 records for axjv.us
# ✅ Inserted 425 records for ayt.us
# ✅ Inserted 730 records for bbp.us
# ✅ Inserted 1118 records for bfor.us
# ✅ Inserted 1118 records for bndx.us
# ✅ Inserted 8 records for bom.us
# ✅ Inserted 1144 records for brzu.us
# ✅ Inserted 1081 records for bscl.us
# ✅ Inserted 1079 records for bscm.us
# ✅ Inserted 780 records for bscn.us
# ✅ Inserted 783 records for bsco.us
# ✅ Inserted 1040 records for bsjj.us
# ✅ Inserted 1038 records for bsjk.us
# ✅ Inserted 788 records for bsjl.us
# ✅ Inserted 787 records for bsjm.us
# ✅ Inserted 822 records for byld.us
# ✅ Inserted 1137 records for cape.us
# ✅ Inserted 685 records for cbon.us
# ✅ Inserted 981 records for cefl.us
# ✅ Inserted 618 records for chau.us
# ✅ Inserted 976 records for chep.us
# ✅ Inserted 617 records for cjnk.us
# ✅ Inserted 820 records for cmdt.us
# ✅ Inserted 778 records for cn.us
# ✅ Inserted 265 records for cntr.us
# ✅ Inserted 826 records for cnxt.us
# ✅ Inserted 766 records for comt.us
# ✅ Inserted 1219 records for cper.us
# ✅ Inserted 708 records for crbn.us
# ✅ Inserted 655 records for ctnn.us
# ✅ Inserted 553 records for cupm.us
# ✅ Inserted 671 records for dbap.us
# ✅ Inserted 822 records for dbaw.us
# ✅ Inserted 1032 records for dbeu.us
# ✅ Inserted 722 records for dbez.us
# ✅ Inserted 763 records for dbko.us
# ✅ Inserted 464 records for dbmx.us
# ✅ Inserted 480 records for dbuk.us
# ✅ Inserted 8 records for dcng.us
# ✅ Inserted 4 records for ddp.us
# ✅ Inserted 1072 records for dgre.us
# ✅ Inserted 862 records for dgro.us
# ✅ Inserted 1079 records for dgrs.us
# ✅ Inserted 1127 records for dgrw.us
# ✅ Inserted 30 records for dirt.us
# ✅ Inserted 616 records for drip.us
# ✅ Inserted 1002 records for dvhl.us
# ✅ Inserted 1015 records for dxge.us
# ✅ Inserted 591 records for dxjc.us
# ✅ Inserted 855 records for dxjf.us
# ✅ Inserted 688 records for dxjh.us
# ✅ Inserted 864 records for dxjr.us
# ✅ Inserted 1100 records for dxjs.us
# ✅ Inserted 1060 records for dxps.us
# ✅ Inserted 902 records for edog.us
# ✅ Inserted 1077 records for eeh.us
# ✅ Inserted 790 records for efad.us
# ✅ Inserted 500 records for effe.us
# ✅ Inserted 843 records for emcg.us
# ✅ Inserted 987 records for emfm.us
# ✅ Inserted 417 records for emih.us
# ✅ Inserted 760 records for emsh.us
# ✅ Inserted 1005 records for enfr.us
# ✅ Inserted 722 records for eqal.us
# ✅ Inserted 779 records for eqlt.us
# ✅ Inserted 571 records for eqwl.us
# ✅ Inserted 559 records for eqwm.us
# ✅ Inserted 499 records for eqws.us
# ✅ Inserted 412 records for ero.us
# ✅ Inserted 861 records for eudg.us
# ✅ Inserted 1117 records for eufx.us
# ✅ Inserted 845 records for eumv.us
# ✅ Inserted 949 records for eurl.us
# ✅ Inserted 618 records for eusc.us
# ✅ Inserted 617 records for faus.us
# ✅ Inserted 858 records for fbgx.us
# ✅ Inserted 776 records for fbnd.us
# ✅ Inserted 1018 records for fcom.us
# ✅ Inserted 769 records for fcor.us
# ✅ Inserted 1018 records for fdis.us
# ✅ Inserted 753 records for fdiv.us
# ✅ Inserted 855 records for fdts.us
# ✅ Inserted 1125 records for feeu.us
# ✅ Inserted 459 records for femb.us
# ✅ Inserted 1018 records for feny.us
# ✅ Inserted 606 records for feuz.us
# ✅ Inserted 962 records for fhk.us
# ✅ Inserted 1018 records for fhlc.us
# ✅ Inserted 1018 records for fidu.us
# ✅ Inserted 1 records for fieg.us
# ✅ Inserted 1040 records for fieu.us
# ✅ Inserted 1125 records for figy.us
# ✅ Inserted 703 records for finz.us
# ✅ Inserted 1093 records for fko.us
# ✅ Inserted 1049 records for flag.us
# ✅ Inserted 858 records for flge.us
# ✅ Inserted 314 records for flrt.us
# ✅ Inserted 776 records for fltb.us
# ✅ Inserted 1018 records for fmat.us
# ✅ Inserted 820 records for fmb.us
# ✅ Inserted 909 records for fmf.us
# ✅ Inserted 1018 records for fncl.us
# ✅ Inserted 1067 records for fnda.us
# ✅ Inserted 1067 records for fndb.us
# ✅ Inserted 1067 records for fndc.us
# ✅ Inserted 1067 records for fnde.us
# ✅ Inserted 1067 records for fndf.us
# ✅ Inserted 1067 records for fndx.us
# ✅ Inserted 18 records for foil.us
# ✅ Inserted 916 records for fpl.us
# ✅ Inserted 630 records for fpxi.us
# ✅ Inserted 696 records for frel.us
# ✅ Inserted 1018 records for fsta.us
# ✅ Inserted 1018 records for ftec.us
# ✅ Inserted 1009 records for ftgc.us
# ✅ Inserted 809 records for fthi.us
# ✅ Inserted 699 records for ftlb.us
# ✅ Inserted 766 records for ftls.us
# ✅ Inserted 623 records for ftsd.us
# ✅ Inserted 792 records for ftsm.us
# ✅ Inserted 680 records for ftw.us
# ✅ Inserted 39 records for fue.us
# ✅ Inserted 1018 records for futy.us
# ✅ Inserted 929 records for fv.us
# ✅ Inserted 1143 records for fwdd.us
# ✅ Inserted 1082 records for fwdi.us
# ✅ Inserted 14 records for fxch.us
# ✅ Inserted 583 records for fxeu.us
# ✅ Inserted 556 records for fxsg.us
# ✅ Inserted 988 records for fyld.us
# ✅ Inserted 727 records for gaa.us
# ✅ Inserted 1277 records for gbb.us
# ✅ Inserted 693 records for gdxs.us
# ✅ Inserted 690 records for gdxx.us
# ✅ Inserted 894 records for geur.us
# ✅ Inserted 568 records for ghii.us
# ✅ Inserted 750 records for gmom.us
# ✅ Inserted 970 records for gqre.us
# ✅ Inserted 6 records for grwn.us
# ✅ Inserted 617 records for gush.us
# ✅ Inserted 922 records for gval.us
# ✅ Inserted 909 records for gyen.us
# ✅ Inserted 899 records for heco.us
# ✅ Inserted 769 records for heem.us
# ✅ Inserted 853 records for hefa.us
# ✅ Inserted 7 records for hevy.us
# ✅ Inserted 889 records for hewg.us
# ✅ Inserted 925 records for hewj.us
# ✅ Inserted 795 records for hezu.us
# ✅ Inserted 258 records for hold.us
# ✅ Inserted 1078 records for hspx.us
# ✅ Inserted 1037 records for huse.us
# ✅ Inserted 821 records for hygh.us
# ✅ Inserted 514 records for hyih.us
# ✅ Inserted 779 records for hynd.us
# ✅ Inserted 870 records for hyzd.us
# ✅ Inserted 1078 records for ibcc.us
# ✅ Inserted 1083 records for ibcd.us
# ✅ Inserted 1054 records for ibce.us
# ✅ Inserted 1066 records for ibdb.us
# ✅ Inserted 1035 records for ibdc.us
# ✅ Inserted 1012 records for ibdd.us
# ✅ Inserted 790 records for ibdh.us
# ✅ Inserted 617 records for ibdj.us
# ✅ Inserted 616 records for ibdk.us
# ✅ Inserted 714 records for ibdl.us
# ✅ Inserted 612 records for ibdm.us
# ✅ Inserted 638 records for ibdn.us
# ✅ Inserted 622 records for ibdo.us
# ✅ Inserted 625 records for ibdp.us
# ✅ Inserted 604 records for ibdq.us
# ✅ Inserted 802 records for ibln.us
# ✅ Inserted 944 records for ibmh.us
# ✅ Inserted 809 records for ibmi.us
# ✅ Inserted 524 records for ici.us
# ✅ Inserted 966 records for icol.us
# ✅ Inserted 1100 records for idog.us
# ✅ Inserted 861 records for ieur.us
# ✅ Inserted 833 records for ifv.us
# ✅ Inserted 556 records for igih.us
# ✅ Inserted 874 records for ihdg.us
# ✅ Inserted 575 records for imtm.us
# ✅ Inserted 117 records for inr.us
# ✅ Inserted 580 records for intf.us
# ✅ Inserted 1181 records for ioil.us
# ✅ Inserted 862 records for ipac.us
# ✅ Inserted 928 records for ipkw.us
# ✅ Inserted 1016 records for ipo.us
# ✅ Inserted 1062 records for iqde.us
# ✅ Inserted 945 records for iqdy.us
# ✅ Inserted 554 records for iqlt.us
# ✅ Inserted 462 records for iscf.us
# ✅ Inserted 1101 records for isra.us
# ✅ Inserted 816 records for iusb.us
# ✅ Inserted 1032 records for jdst.us
# ✅ Inserted 555 records for jhdg.us
# ✅ Inserted 237 records for jjs.us
# ✅ Inserted 106 records for jjt.us
# ✅ Inserted 1032 records for jnug.us
# ✅ Inserted 831 records for jpge.us
# ✅ Inserted 809 records for jpmv.us
# ✅ Inserted 1100 records for jpnl.us
# ✅ Inserted 844 records for kba.us
# ✅ Inserted 679 records for kfyp.us
# ✅ Inserted 1117 records for koru.us
# ✅ Inserted 618 records for labd.us
# ✅ Inserted 618 records for labu.us
# ✅ Inserted 743 records for lalt.us
# ✅ Inserted 574 records for ldri.us
# ✅ Inserted 857 records for ldur.us
# ✅ Inserted 1088 records for lglv.us
# ✅ Inserted 119 records for llsc.us
# ✅ Inserted 453 records for llsp.us
# ✅ Inserted 659 records for lmbs.us
# ✅ Inserted 849 records for lmlp.us
# ✅ Inserted 590 records for lowc.us
# ✅ Inserted 771 records for lqdh.us
# ✅ Inserted 594 records for lrgf.us
# ✅ Inserted 149 records for lstk.us
# ✅ Inserted 723 records for mbsd.us
# ✅ Inserted 967 records for mlpc.us
# ✅ Inserted 7 records for mlps.us
# ✅ Inserted 1071 records for mlpx.us
# ✅ Inserted 771 records for mmtm.us
# ✅ Inserted 934 records for mom.us
# ✅ Inserted 651 records for mrgr.us
# ✅ Inserted 693 records for nash.us
# ✅ Inserted 1039 records for near.us
# ✅ Inserted 1006 records for nfra.us
# ✅ Inserted 1159 records for nge.us
# ✅ Inserted 160 records for nini.us
# ✅ Inserted 1027 records for nobl.us
# ✅ Inserted 1113 records for olem.us
# ✅ Inserted 879 records for ounz.us
# ✅ Inserted 583 records for pak.us
# ✅ Inserted 722 records for pdbc.us
# ✅ Inserted 1008 records for pex.us
# ✅ Inserted 993 records for pgal.us
# ✅ Inserted 1105 records for pghy.us
# ✅ Inserted 739 records for qat.us
# ✅ Inserted 724 records for qcan.us
# ✅ Inserted 663 records for qdeu.us
# ✅ Inserted 1042 records for qdyn.us
# ✅ Inserted 119 records for qed.us
# ✅ Inserted 661 records for qefa.us
# ✅ Inserted 736 records for qemm.us
# ✅ Inserted 457 records for qgbr.us
# ✅ Inserted 857 records for qinc.us
# ✅ Inserted 577 records for qjpn.us
# ✅ Inserted 39 records for qls.us
# ✅ Inserted 1113 records for qmn.us
# ✅ Inserted 1086 records for qual.us
# ✅ Inserted 408 records for qus.us
# ✅ Inserted 497 records for qwld.us
# ✅ Inserted 978 records for qyld.us
# ✅ Inserted 1036 records for rdiv.us
# ✅ Inserted 946 records for rdvy.us
# ✅ Inserted 835 records for reet.us
# ✅ Inserted 674 records for regl.us
# ✅ Inserted 1029 records for rigs.us
# ✅ Inserted 724 records for rinf.us
# ✅ Inserted 1020 records for robo.us
# ✅ Inserted 2 records for rola.us
# ✅ Inserted 1032 records for rvnu.us
# ✅ Inserted 106 records for sagg.us
# ✅ Inserted 720 records for sbio.us
# ✅ Inserted 20 records for sbm.us
# ✅ Inserted 8 records for scc.us
# ✅ Inserted 396 records for scid.us
# ✅ Inserted 318 records for scij.us
# ✅ Inserted 551 records for sciu.us
# ✅ Inserted 371 records for scix.us
# ✅ Inserted 657 records for scto.us
# ✅ Inserted 589 records for sdem.us
# ✅ Inserted 1 records for sgar.us
# ✅ Inserted 618 records for sgdj.us
# ✅ Inserted 838 records for sgdm.us
# ✅ Inserted 949 records for shyd.us
# ✅ Inserted 1021 records for shyg.us
# ✅ Inserted 69 records for siz.us
# ✅ Inserted 984 records for size.us
# ✅ Inserted 650 records for skor.us
# ✅ Inserted 997 records for slqd.us
# ✅ Inserted 1152 records for slvo.us
# ✅ Inserted 668 records for smdv.us
# ✅ Inserted 816 records for smez.us
# ✅ Inserted 528 records for smlf.us
# ✅ Inserted 141 records for smll.us
# ✅ Inserted 1139 records for smlv.us
# ✅ Inserted 614 records for splx.us
# ✅ Inserted 829 records for spuu.us
# ✅ Inserted 1058 records for spxh.us
# ✅ Inserted 531 records for spyb.us
# ✅ Inserted 663 records for sret.us
# ✅ Inserted 539 records for sye.us
# ✅ Inserted 714 records for syg.us
# ✅ Inserted 1132 records for syld.us
# ✅ Inserted 464 records for syv.us
# ✅ Inserted 49 records for tags.us
# ✅ Inserted 771 records for tflo.us
# ✅ Inserted 898 records for tipx.us
# ✅ Inserted 901 records for tolz.us
# ✅ Inserted 681 records for totl.us
# ✅ Inserted 927 records for trsk.us
# ✅ Inserted 552 records for tusa.us
# ✅ Inserted 1134 records for tybs.us
# ✅ Inserted 3 records for tyns.us
# ✅ Inserted 837 records for uae.us
# ✅ Inserted 79 records for uag.us
# ✅ Inserted 205 records for ubc.us
# ✅ Inserted 2 records for ubg.us
# ✅ Inserted 43 records for ubm.us
# ✅ Inserted 605 records for ubn.us
# ✅ Inserted 12 records for ujb.us
# ✅ Inserted 983 records for ulst.us
# ✅ Inserted 550 records for urr.us
# ✅ Inserted 6 records for usag.us
# ✅ Inserted 880 records for usdu.us
# ✅ Inserted 48 records for usfr.us
# ✅ Inserted 1046 records for vega.us
# ✅ Inserted 1011 records for vidi.us
# ✅ Inserted 1198 records for viiz.us
# ✅ Inserted 581 records for vlu.us
# ✅ Inserted 1068 records for vlue.us
# ✅ Inserted 889 records for vrp.us
# ✅ Inserted 958 records for vuse.us
# ✅ Inserted 1118 records for vwob.us
# ✅ Inserted 1103 records for wdiv.us
# ✅ Inserted 28 records for weet.us
# ✅ Inserted 618 records for xrlv.us
# ✅ Inserted 431 records for xsoe.us
# ✅ Inserted 618 records for xt.us
# ✅ Inserted 1025 records for ydiv.us
# ✅ Inserted 603 records for ylco.us
# ✅ Inserted 946 records for zmlp.us
# All data uploaded!
